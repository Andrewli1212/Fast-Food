# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint

# %%
food_path = 'FastFoodRestaurants.csv'
food_db = pd.read_csv(food_path)
food_db
# Out:
#                     address                    city country  \
# 0               324 Main St                 Massena      US
# 1           530 Clinton Ave  Washington Court House      US
# 2      408 Market Square Dr               Maysville      US
# 3     6098 State Highway 37                 Massena      US
# 4           139 Columbus Rd                  Athens      US
# ...                     ...                     ...     ...
# 9995  3013 Peach Orchard Rd                 Augusta      US
# 9996      678 Northwest Hwy                    Cary      US
# 9997           1708 Main St                Longmont      US
# 9998      67740 Highway 111          Cathedral City      US
# 9999    5701 E La Palma Ave                 Anaheim      US
#
#                                                    keys   latitude  \
# 0                   us/ny/massena/324mainst/-1161002137  44.921300
# 1     us/oh/washingtoncourthouse/530clintonave/-7914...  39.532550
# ...

# %%
count = food_db['name'].nunique()
count
# Out:
# 548

# %%
food_db = food_db.drop(columns=['websites', 'keys'])
food_db
# Out:
#                     address                    city country   latitude  \
# 0               324 Main St                 Massena      US  44.921300
# 1           530 Clinton Ave  Washington Court House      US  39.532550
# 2      408 Market Square Dr               Maysville      US  38.627360
# 3     6098 State Highway 37                 Massena      US  44.950080
# 4           139 Columbus Rd                  Athens      US  39.351550
# ...                     ...                     ...     ...        ...
# 9995  3013 Peach Orchard Rd                 Augusta      US  33.415257
# 9996      678 Northwest Hwy                    Cary      US  42.217300
# 9997           1708 Main St                Longmont      US  40.189190
# 9998      67740 Highway 111          Cathedral City      US  33.788640
# 9999    5701 E La Palma Ave                 Anaheim      US  33.860074
#
#        longitude                         name postalCode province
# ...

# %%
food_db = food_db.rename(columns={'province':'state', 'postalCode':'postal_code', 'name':'restaurant'})
food_db
# Out:
#                     address                    city country   latitude  \
# 0               324 Main St                 Massena      US  44.921300
# 1           530 Clinton Ave  Washington Court House      US  39.532550
# 2      408 Market Square Dr               Maysville      US  38.627360
# 3     6098 State Highway 37                 Massena      US  44.950080
# 4           139 Columbus Rd                  Athens      US  39.351550
# ...                     ...                     ...     ...        ...
# 9995  3013 Peach Orchard Rd                 Augusta      US  33.415257
# 9996      678 Northwest Hwy                    Cary      US  42.217300
# 9997           1708 Main St                Longmont      US  40.189190
# 9998      67740 Highway 111          Cathedral City      US  33.788640
# 9999    5701 E La Palma Ave                 Anaheim      US  33.860074
#
#        longitude                   restaurant postal_code state
# ...

# %%
food_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   address      10000 non-null  object
#  1   city         10000 non-null  object
#  2   country      10000 non-null  object
#  3   latitude     10000 non-null  float64
#  4   longitude    10000 non-null  float64
#  5   restaurant   10000 non-null  object
#  6   postal_code  10000 non-null  object
#  7   state        10000 non-null  object
# dtypes: float64(2), object(6)
# memory usage: 625.1+ KB

# %%
food_db['restaurant'] = food_db['restaurant'].astype(str).astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 food_db['restaurant'] = food_db['restaurant'].astype(str).astype(int)
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
pd.pivot_table(food_db, values='name',
              index=['province', 'name'],
              columns=['name']
              )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 pd.pivot_table(food_db, values='name',
#       2               index=['province', 'name'],
#       3               columns=['name']
#       4               )
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\reshape\pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      94     table = concat(pieces, keys=keys, axis=1)
#      95     return table.__finalize__(data, method="pivot_table")
# ---> 97 table = __internal_pivot_table(
#      98     data,
#      99     values,
#     100     index,
#     101     columns,
#     102     aggfunc,
#     103     fill_value,
#     104     margins,
#     105     dropna,
#     106     margins_name,
#     107     observed,
#     108     sort,
#     109 )
# ...
